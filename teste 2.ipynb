# %%
from skimage.io import imsave, imread
import numpy as np
from skimage.color import rgb2gray
from skimage.filters import sobel
from skimage.exposure import rescale_intensity
import matplotlib.pyplot as plt
from skimage import img_as_float32
import math as mt
# %matplotlib inline

# %%
imagem = imread('IMD002.bmp')
plt.imshow(imagem)

# %%
gx = imagem.copy()
gy = imagem.copy()
CV_32F = img_as_float32(imagem)

sobel(imagem, gx, CV_32F, 1, 0, 1)
sobel(imagem, gy, CV_32F, 0, 1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9f93abd05a16> in <module>()
#       3 CV_32F = img_as_float32(imagem)
#       4
# ----> 5 sobel(imagem, gx, CV_32F, 1, 0, 1)
#       6 sobel(imagem, gy, CV_32F, 0, 1, 1)
#
# TypeError: sobel() takes from 1 to 2 positional arguments but 6 were given
